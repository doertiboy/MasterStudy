# %%
import numpy as np
import pandas as pd
import csv
from matplotlib import pyplot as plt
from scipy.integrate import trapz
from scipy.signal import find_peaks

# %%
# %store -r acc_dict
# %store -r jerk_values
person_names = ["p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8", "p9", "p10", "p11", "p12", "p13", "p14", "p15", "p16", "p17", "p18"]

# %%
jerks = np.zeros(len(person_names))
times = np.zeros(len(person_names))
genders = []

for i, person_name in enumerate(person_names):
    jerk_data = jerk_values['vector']
    acc_data = acc_dict[person_name]

    jerks[i] = jerk_data[person_name]
    times[i] = len(acc_data['time']) - 1
    genders.append(str(acc_data['gender'].values))  

genders = np.array(genders)

# Plotting
plt.figure(figsize=(8, 6))
for gender in np.unique(genders):
    color = 'red' if gender == 'female' else 'blue'
    gender_indices = np.where(genders == gender)[0]
    plt.scatter(times[gender_indices], jerks[gender_indices], color=color, label=gender)

plt.xlabel('Time')
plt.ylabel('Jerk')
plt.title('Scatter Plot of Times vs Jerks by Gender')
plt.legend()
plt.grid(True)
plt.show()
